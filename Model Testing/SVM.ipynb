# %% [markdown]
# #### Preliminaries

# %%
import sys
import os
import numpy as np
import pandas as pd
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
sys.path.append(os.path.dirname(os.getcwd()))
from Technical_Indicators.Mean_Reversion.data_prep import fetch_data, time_series_features, add_lag_features, apply_jcandle, simple_moving_average
import pandas_ta as ta

# %% [markdown]
# #### Fetch Data

# %%
xom_df = fetch_data('XOM', '2000-01-01', '2023-12-31')

# %% [markdown]
# #### Data Prep

# %%
xom_df['MA30_shifted'] = simple_moving_average(xom_df, 30).shift(1)

# %%
xom_df
# Out:
#                                  Open        High        Low      Close  \
# Date
# 2000-01-03 00:00:00-05:00   18.309310   18.597192  17.935063  18.035822
# 2000-01-04 00:00:00-05:00   17.819906   18.007029  17.618389  17.690359
# 2000-01-05 00:00:00-05:00   17.963854   18.827501  17.920672  18.654772
# 2000-01-06 00:00:00-05:00   18.568401   19.763112  18.467642  19.619171
# 2000-01-07 00:00:00-05:00   19.791894   19.863864  19.345677  19.561588
# ...                               ...         ...        ...        ...
# 2023-12-22 00:00:00-05:00   99.748148  100.362377  99.270419  99.358170
# 2023-12-26 00:00:00-05:00  100.167372  100.450111  99.562902  99.582397
# 2023-12-27 00:00:00-05:00   99.484900   99.982132  98.802424  99.114418
# 2023-12-28 00:00:00-05:00   98.851177   99.065670  97.622726  97.681229
# 2023-12-29 00:00:00-05:00   97.856720   98.071205  97.125500  97.476486
#
#                              Volume  Dividends  Stock Splits       MA30  \
# Date
# ...
